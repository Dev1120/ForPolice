# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev1120/ForPolice/blob/hagyung0208/%EC%8B%9C%EA%B0%81%ED%99%94_0209_%EC%88%98%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 폰트 설치 이후 런타임 다시시작

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 0s (41.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
plt.rc('font', family = 'NanumBarunGothic')

# %%
sort_local = pd.read_csv('/content/gdrive/MyDrive/Local/Data/주소포함_전체정리.csv')
sort_local
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        RECV_DEPT_NM         RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  \
# 0               충남청  2020-01-01 00:03:11      19           10        406
# 1               충남청  2020-01-01 00:18:08      19           10        403
# 2               충남청  2020-01-01 00:20:01      19           10        406
# 3               충남청  2020-01-01 00:20:04      19           10        402
# 4               대전청  2020-01-01 00:21:35      13           10        401
# ...             ...                  ...     ...          ...        ...
# 415065          대전청  2023-01-18 23:23:38      13           10        406
# 415066          충남청  2023-01-18 23:32:32      19           10        401
# 415067          충남청  2023-01-18 23:34:30      19           10        401
# ...

# %%
sort_local[sort_local['구분'] == '충남']['시/군/구'].value_counts()
# Out:
# 천안시    74681
# 아산시    34823
# 당진시    20933
# 서산시    18589
# 공주시    14616
# 논산시    12941
# 보령시    12783
# 홍성군    10134
# 예산군     7820
# 태안군     6624
# 서천군     4605
# 부여군     4512
# 금산군     4499
# 계룡시     2133
# 청양군     2119
# Name: 시/군/구, dtype: int64

# %%
print('교통사고 발생건수: ', len(sort_local[sort_local['EVT_CL_CD'] == 401]))
print('교통불편 발생건수: ', len(sort_local[sort_local['EVT_CL_CD'] == 402]))
print('교통위반 발생건수: ', len(sort_local[sort_local['EVT_CL_CD'] == 403]))
print('사망, 대형사고 발생건수: ', len(sort_local[sort_local['EVT_CL_CD'] == 404]))
print('인피도주 발생건수: ', len(sort_local[sort_local['EVT_CL_CD'] == 405]))
print('음주운전 발생건수: ', len(sort_local[sort_local['EVT_CL_CD'] == 406]))
# Out:
# 교통사고 발생건수:  255225
# 교통불편 발생건수:  58505
# 교통위반 발생건수:  33519
# 사망, 대형사고 발생건수:  21
# 인피도주 발생건수:  45
# 음주운전 발생건수:  67755

# %%
sort_local_401 = len(sort_local[sort_local['EVT_CL_CD'] == 401])
sort_local_402 = len(sort_local[sort_local['EVT_CL_CD'] == 402])
sort_local_403 = len(sort_local[sort_local['EVT_CL_CD'] == 403])
sort_local_404 = len(sort_local[sort_local['EVT_CL_CD'] == 404])
sort_local_405 = len(sort_local[sort_local['EVT_CL_CD'] == 405])
sort_local_406 = len(sort_local[sort_local['EVT_CL_CD'] == 406])

sort_local_type = [["교통사고",sort_local_401],["교통불편",sort_local_402],["교통위반",sort_local_403],["사망,대형사고",sort_local_404],["인피도주",sort_local_405],
        ["음주운전",sort_local_406]]

sort_local_type = pd.DataFrame(sort_local_type, columns = ['type', 'count'])

# %%
sort_local_type.plot(x = 'type', kind = 'bar', figsize = (10, 5))
plt.title('전체 지역 사고 타입')
# Out:
# Text(0.5, 1.0, '전체 지역 사고 타입')

# %%
sort_local_city_dj = len(sort_local[sort_local['RECV_DEPT_NM'] == '대전청'])
sort_local_city_cn = len(sort_local[sort_local['RECV_DEPT_NM'] == '충남청'])

sort_local_city=[["대전청",sort_local_city_dj],['충남청', sort_local_city_cn]]
sort_local_city = pd.DataFrame(sort_local_city, columns = ['지역', 'count'])

# %%
sort_local_city.plot(x = '지역', kind = 'bar', figsize = (10, 10))

# %%
sort_local_city_cn = len(sort_local[sort_local['구분'] == '충남'])
sort_local_city_dj = len(sort_local[sort_local['구분'] == '대전'])
sort_local_city_sj = len(sort_local[sort_local['구분'] == '세종'])


sort_local_city=[["충남",sort_local_city_cn],['대전', sort_local_city_dj], ['세종', sort_local_city_sj]]
sort_local_city = pd.DataFrame(sort_local_city, columns = ['구분', '신고 수'])

# %%
sort_local_city.plot(x = '구분', kind = 'bar', figsize = (10, 10))

# %%
sort_local.head(5)
# Out:
#   RECV_DEPT_NM         RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD RPTER_SEX  \
# 0          충남청  2020-01-01 00:03:11      19           10        406         1
# 1          충남청  2020-01-01 00:18:08      19           10        403         1
# 2          충남청  2020-01-01 00:20:01      19           10        406         1
# 3          충남청  2020-01-01 00:20:04      19           10        402         1
# 4          대전청  2020-01-01 00:21:35      13           10        401         1
#
#                    HPPN_PNU_ADDR      HPPN_X     HPPN_Y SME_EVT_YN         요일  \
# 0     충청남도 공주시 정안면 어물리(정안면) 33-2  127.148714  36.605751          Y  Wednesday
# 1      충청남도 논산시 채운면 장화리(채운면) 533  127.030921  36.164643        NaN  Wednesday
# 2     세종특별자치시 세종시 소담동(소담동) 32-92  127.305511  36.479819          Y  Wednesday
# 3    충청남도 천안시 서북구 불당동(불당동) 204-4  127.109667  36.815468        NaN  Wednesday
# 4  대전광역시 유성구 봉명동(행정:온천1동) 541-26  127.348625  36.353829        NaN  Wednesday
#
#    구분 시/군/구
# 0  충남   공주시
# ...

# %%
condition_CN = (sort_local['구분'] == '충남')
condition_DJ = (sort_local['구분'] == '대전')
condition_SJ = (sort_local['구분'] == '세종')

sort_local_CN = sort_local[condition_CN]
sort_local_DJ = sort_local[condition_DJ]
sort_local_SJ = sort_local[condition_SJ]

# %%
sort_local_CN
# Out:
#        RECV_DEPT_NM         RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  \
# 0               충남청  2020-01-01 00:03:11      19           10        406
# 1               충남청  2020-01-01 00:18:08      19           10        403
# 3               충남청  2020-01-01 00:20:04      19           10        402
# 6               충남청  2020-01-01 00:29:48      19           10        403
# 7               충남청  2020-01-01 00:32:03      19           10        406
# ...             ...                  ...     ...          ...        ...
# 415056          충남청  2023-01-18 22:50:32      19           10        401
# 415061          충남청  2023-01-18 23:09:14      19           10        406
# 415066          충남청  2023-01-18 23:32:32      19           10        401
# 415067          충남청  2023-01-18 23:34:30      19           10        401
# 415069          충남청  2023-01-18 23:59:40      19           10        406
#
#        RPTER_SEX                     HPPN_PNU_ADDR      HPPN_X     HPPN_Y  \
# ...

# %%
A = pd.concat([sort_local_CN, sort_local_DJ, sort_local_SJ], axis = 0)
A
# Out:
#        RECV_DEPT_NM         RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  \
# 0               충남청  2020-01-01 00:03:11      19           10        406
# 1               충남청  2020-01-01 00:18:08      19           10        403
# 3               충남청  2020-01-01 00:20:04      19           10        402
# 6               충남청  2020-01-01 00:29:48      19           10        403
# 7               충남청  2020-01-01 00:32:03      19           10        406
# ...             ...                  ...     ...          ...        ...
# 415044          충남청  2023-01-18 22:03:37      31           10        403
# 415047          충남청  2023-01-18 22:10:04      31           10        401
# 415054          충남청  2023-01-18 22:48:29      31           10        401
# 415057          충남청  2023-01-18 23:02:07      31           10        406
# 415058          충남청  2023-01-18 23:04:08      31           10        406
#
#        RPTER_SEX                        HPPN_PNU_ADDR      HPPN_X     HPPN_Y  \
# ...

# %%
sort_local_CN.head(5)
# Out:
#   RECV_DEPT_NM         RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD RPTER_SEX  \
# 0          충남청  2020-01-01 00:03:11      19           10        406         1
# 1          충남청  2020-01-01 00:18:08      19           10        403         1
# 3          충남청  2020-01-01 00:20:04      19           10        402         1
# 6          충남청  2020-01-01 00:29:48      19           10        403         1
# 7          충남청  2020-01-01 00:32:03      19           10        406         1
#
#                       HPPN_PNU_ADDR      HPPN_X     HPPN_Y SME_EVT_YN  \
# 0        충청남도 공주시 정안면 어물리(정안면) 33-2  127.148714  36.605751          Y
# 1         충청남도 논산시 채운면 장화리(채운면) 533  127.030921  36.164643        NaN
# 3       충청남도 천안시 서북구 불당동(불당동) 204-4  127.109667  36.815468        NaN
# 6  충청남도 천안시 동남구 목천읍 삼성리(목천읍) 203-19  127.170556  36.762500        NaN
# 7        충청남도 서산시 읍내동(행정:부춘동) 585-1  126.444094  36.786189        NaN
#
#           요일  구분 시/군/구
# 0  Wednesday  충남   공주시
# 1  Wednesday  충남   논산시
# ...

# %%
print('교통사고 발생건수: ', len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 401]))
print('교통불편 발생건수: ', len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 402]))
print('교통위반 발생건수: ', len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 403]))
print('사망, 대형사고 발생건수: ', len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 404]))
print('인피도주 발생건수: ', len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 405]))
print('음주운전 발생건수: ', len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 406]))
# Out:
# 교통사고 발생건수:  137726
# 교통불편 발생건수:  30266
# 교통위반 발생건수:  19801
# 사망, 대형사고 발생건수:  19
# 인피도주 발생건수:  19
# 음주운전 발생건수:  43981

# %%
CN401 = len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 401])
CN402 = len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 402])
CN403 = len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 403])
CN404 = len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 404])
CN405 = len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 405])
CN406 = len(sort_local_CN[sort_local_CN['EVT_CL_CD'] == 406])

CN_type = [["교통사고", CN401],["교통불편", CN402],["교통위반", CN403],["사망,대형사고",CN404],["인피도주", CN405],
        ["음주운전", CN406]]

CN_type = pd.DataFrame(CN_type, columns = ['type', 'count'])

# %%
CN_type.plot(x = 'type', kind = 'bar')
plt.title('충남 사고 타입')
# Out:
# Text(0.5, 1.0, '충남 사고 타입')

# %%
print('교통사고 발생건수: ', len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 401]))
print('교통불편 발생건수: ', len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 402]))
print('교통위반 발생건수: ', len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 403]))
print('사망, 대형사고 발생건수: ', len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 404]))
print('인피도주 발생건수: ', len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 405]))
print('음주운전 발생건수: ', len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 406]))
# Out:
# 교통사고 발생건수:  104079
# 교통불편 발생건수:  23778
# 교통위반 발생건수:  11373
# 사망, 대형사고 발생건수:  2
# 인피도주 발생건수:  17
# 음주운전 발생건수:  19214

# %%
DJ401 = len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 401])
DJ402 = len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 402])
DJ403 = len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 403])
DJ404 = len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 404])
DJ405 = len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 405])
DJ406 = len(sort_local_DJ[sort_local_DJ['EVT_CL_CD'] == 406])

# %%
DJ_type = [["교통사고", DJ401],["교통불편", DJ402],["교통위반", DJ403],["사망,대형사고", DJ404],["인피도주", DJ405],
        ["음주운전", DJ406]]

DJ_type = pd.DataFrame(DJ_type, columns = ['type', 'count'])

# %%
DJ_type.plot(x = 'type', kind = 'bar')
plt.title('대전 사고 타입')
# Out:
# Text(0.5, 1.0, '대전 사고 타입')

# %%
SJ401 = len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 401])
SJ402 = len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 402])
SJ403 = len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 403])
SJ404 = len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 404])
SJ405 = len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 405])
SJ406 = len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 406])

SJ_type = [["교통사고", SJ401],["교통불편", SJ402],["교통위반", SJ403],["사망,대형사고", SJ404],["인피도주", SJ405],
        ["음주운전", SJ406]]

SJ_type = pd.DataFrame(SJ_type, columns = ['type', 'count'])

# %%
print('교통사고 발생건수: ', len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 401]))
print('교통불편 발생건수: ', len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 402]))
print('교통위반 발생건수: ', len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 403]))
print('사망, 대형사고 발생건수: ', len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 404]))
print('인피도주 발생건수: ', len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 405]))
print('음주운전 발생건수: ', len(sort_local_SJ[sort_local_SJ['EVT_CL_CD'] == 406]))
# Out:
# 교통사고 발생건수:  13420
# 교통불편 발생건수:  4461
# 교통위반 발생건수:  2345
# 사망, 대형사고 발생건수:  0
# 인피도주 발생건수:  9
# 음주운전 발생건수:  4560

# %%
SJ_type.plot(x = 'type', kind = 'bar')
plt.title('세종 사고 타입')
# Out:
# Text(0.5, 1.0, '세종 사고 타입')
