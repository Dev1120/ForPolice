# %% [markdown]
# 일단은...01/29 에
#
# 관련 기사, 논문, 데이터 찾아보기
#
# 동탄 언제갈지 정하기
#
# 하기로 했습니다
#
# 화면도 잘 보이시죠?
#
# 주제 : [음주운전+교통사고 발생건수 / 시간 + 요일 + 지역 + 경찰 수] 을 통해서 발생지역 예측 OR 발생 시간대 & 요일 예측해서 인력배치를 얼마나 할지
#
# 통계팀
#     - 스터디~
#     - 주소 [구]를 추출, // 구별 사건현황 시각화 (401+406)
#                                 (발생건수, 요일별 발생, 지역별 발생)
#                        - 토요일 밤 10시 회의에 말씀드리겠습니다, 성길 -
#
# 시각화팀
#  - 날씨(+ 가시거리) 변수 추가하자
#  - 앙상블, 랜덤포레스트, m?ap? => 모델마다 중요한 변수가 다 다르니 사용은 니 맘이다
#  - 경찰서 별 긴급신고가 몇 개나 있었는지/ 긴급도에 따른 인력 투입
#      - 시간대를 범주화해서 데이터에 긴급도 가중치? 가산점? 을 줌
#
#
# 변수 추가할거(주의할 점 : !충남, 대전, 세종 지역의 자료여야 함!)
#   - 날씨, 구(주소), 경찰관 수, 단속장비 유무, 신호등 개수, 사고당사자의 총 운전거리,  횡단보도 개수, 유동인구 수, 총 인구수, 동승자 수, 운전면허 소지자의 나이, 음주운전 단속 빈도
#
# ========================================================================
#
# 업무분담 01/30 밤 10시에 시각화 및 자료 공유
#
# - 해당범죄가 몇 건이나 발생했는가? : 성길 / 날씨, 구(주소), 경찰관 수
#
# - 가장 많이 발생한 시간은 언제인가? : 동현 / 단속장비 유무, 신호등 개수, 사고당사자의 총 운전거리
#
# - 요일과 관련이 있는가? : 나은 / 횡단보도 개수, 유동인구 수, 총 인구수
#
# - 가장 많이 발생한 지역은 어디인가? : 하경 / 동승자 수, 운전면허 소지자의 나이, 음주운전 단속 빈도

# %% [markdown]
# ### 그렇다면 기본틀을 어떻게 잡아야할까?
# - 1. 지역선택 :(충남, 대전, 세종)
# - 2. 범죄선택 : 음주운전+교통사고
#
# - 3. 사건현황 분석(해당범죄가 몇 건이나 발생했는가,가장 많이 발생한 시간은 언제인가, 요일과 관련이 있는가, 가장 많이 발생한 지역은 어디인가 ...)
#
# - 4. 알고리즘 제작(후에 예측값 도출)
# - 5. 예측률과 이에 따른 기대효과

# %% [markdown]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77077 entries, 0 to 77076
# Data columns (total 10 columns):
#  #Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RECV_DEPT_NM   77077 non-null  object
#  1   RECV_CPLT_DM   77077 non-null  object
#  2   NPA_CL         77077 non-null  int64
#  3   EVT_STAT_CD    77077 non-null  int64
#  4   EVT_CL_CD      77077 non-null  int64
#  5   RPTER_SEX      74658 non-null  float64
#  6   HPPN_PNU_ADDR  47805 non-null  object
#  7   HPPN_X         60313 non-null  float64
#  8   HPPN_Y         60313 non-null  float64
#  9   SME_EVT_YN     13442 non-null  object

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

# %config InlineBackend.figure_format = 'retina' # 폰트를 선명하게~
# Out:
# C:\Users\minir\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
kp20=pd.read_csv("C:\\Users\\minir\\OneDrive\\바탕 화면\\지치안\\data\\KP2020.csv")

kp21=pd.read_csv("C:\\Users\\minir\\OneDrive\\바탕 화면\\지치안\\data\\KP2021.csv")

# %%
kp20.rename(columns={"RECV_DEPT_NM":"접수부서코드","RECV_CPLT_DM":"접수완료일시", "NPA_CL":"경찰청구분", "EVT_STAT_CD":"사건상태코드","EVT_CL_CD":"사건종별코드","RPTER_SEX":"신고성별","HPPN_PNU_ADDR":"발생지점","HPPN_X":"발생좌표x","HPPN_Y":"발생좌표y","SME_EVT_YN":"동일사건여부"}, inplace=True)
kp21.rename(columns={"RECV_DEPT_NM":"접수부서코드","RECV_CPLT_DM":"접수완료일시", "NPA_CL":"경찰청구분", "EVT_STAT_CD":"사건상태코드","EVT_CL_CD":"사건종별코드","RPTER_SEX":"신고성별","HPPN_PNU_ADDR":"발생지점","HPPN_X":"발생좌표x","HPPN_Y":"발생좌표y","SME_EVT_YN":"동일사건여부"}, inplace=True)

# %%
# 음주운전+교통사고 발생건수
tt= kp20[(kp20["사건종별코드"]==403) | (kp20["사건종별코드"]== 406) |(kp20["사건종별코드"]== 402)|(kp20["사건종별코드"]== 401)|(kp20["사건종별코드"]== 404)|(kp20["사건종별코드"]== 405)]
print(len(tt))
# Out:
# 9343

# %%
# 20년도 각각의 발생건수
print("교통사고 발생건수 :",len(tt[tt["사건종별코드"]==401]))
print("교통불편 발생건수 :",len(tt[tt["사건종별코드"]==402]))
print("교통위반 발생건수 :",len(tt[tt["사건종별코드"]==403]))
print("사망,대형사고 발생건수 :",len(tt[tt["사건종별코드"]==404]))
print("인피도주 발생건수 :",len(tt[tt["사건종별코드"]==405]))
print("음주운전 발생건수 :",len(tt[tt["사건종별코드"]==406]))
# Out:
# 교통사고 발생건수 : 6207
# 교통불편 발생건수 : 1294
# 교통위반 발생건수 : 516
# 사망,대형사고 발생건수 : 0
# 인피도주 발생건수 : 1
# 음주운전 발생건수 : 1325

# %%
tt20_401=len(tt[tt["사건종별코드"]==401])
tt20_402=len(tt[tt["사건종별코드"]==402])
tt20_403=len(tt[tt["사건종별코드"]==403])
tt20_404=len(tt[tt["사건종별코드"]==404])
tt20_405=len(tt[tt["사건종별코드"]==405])
tt20_406=len(tt[tt["사건종별코드"]==406])

# %%
tt_list=[["교통사고",tt20_401],["교통불편",tt20_402],["교통위반",tt20_403],["사망,대형사고",tt20_404],["인피도주",tt20_405],
        ["음주운전",tt20_406]]
tt20df=pd.DataFrame(tt_list, columns=["종류","발생건수"])

# %%
tt20df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종류      6 non-null      object
#  1   발생건수    6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
tt20df=tt20df.set_index("종류").astype(float)
tt20df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 교통사고 to 음주운전
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   발생건수    6 non-null      float64
# dtypes: float64(1)
# memory usage: 96.0+ bytes

# %%
# 20년도 사건 종류별 발생건수

tt20df=tt20df.sort_values("발생건수", ascending=False)

tt20df.plot(kind="bar", figsize=(10,5), color="Skyblue")
plt.xlabel("사건종류")
plt.ylabel("발생건수")
plt.title("<20년도 사건 종류별 발생건수>")
# Out:
# Text(0.5, 1.0, '<20년도 사건 종류별 발생건수>')

# %%
# 21년도 음주운전+교통사고 발생건수
tt21= kp21[(kp21["사건종별코드"]==403) | (kp21["사건종별코드"]== 406) |(kp21["사건종별코드"]== 402)|(kp21["사건종별코드"]== 401)|(kp21["사건종별코드"]== 404)|(kp21["사건종별코드"]== 405)]
print("총 발생건수 :",len(tt21))
# Out:
# 총 발생건수 : 278326

# %%
# 21년도 각각의 발생건수
print("교통사고 발생건수 :",len(tt21[tt21["사건종별코드"]==401]))
print("교통불편 발생건수 :",len(tt21[tt21["사건종별코드"]==402]))
print("교통위반 발생건수 :",len(tt21[tt21["사건종별코드"]==403]))
print("사망,대형사고 발생건수 :",len(tt21[tt21["사건종별코드"]==404]))
print("인피도주 발생건수 :",len(tt21[tt21["사건종별코드"]==405]))
print("음주운전 발생건수 :",len(tt21[tt21["사건종별코드"]==406]))
# Out:
# 교통사고 발생건수 : 164582
# 교통불편 발생건수 : 37443
# 교통위반 발생건수 : 24295
# 사망,대형사고 발생건수 : 16
# 인피도주 발생건수 : 35
# 음주운전 발생건수 : 51955

# %%
tt21_401=len(tt21[tt21["사건종별코드"]==401])
tt21_402=len(tt21[tt21["사건종별코드"]==402])
tt21_403=len(tt21[tt21["사건종별코드"]==403])
tt21_404=len(tt21[tt21["사건종별코드"]==404])
tt21_405=len(tt21[tt21["사건종별코드"]==405])
tt21_406=len(tt21[tt21["사건종별코드"]==406])

tt21_list=[["교통사고",tt21_401],["교통불편",tt21_402],["교통위반",tt21_403],["사망,대형사고",tt21_404],["인피도주",tt21_405],
        ["음주운전",tt21_406]]
tt21df=pd.DataFrame(tt21_list, columns=["종류","발생건수"])

# %%
tt21df=tt21df.set_index("종류").astype(float)
tt21df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 교통사고 to 음주운전
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   발생건수    6 non-null      float64
# dtypes: float64(1)
# memory usage: 96.0+ bytes

# %%
# 20년도 사건 종류별 발생건수

tt21df=tt21df.sort_values("발생건수", ascending=False)

tt21df.plot(kind="bar", figsize=(10,5), color="Skyblue")
plt.xlabel("사건종류")
plt.ylabel("발생건수")
plt.title("<21년도 사건 종류별 발생건수>")
# Out:
# Text(0.5, 1.0, '<21년도 사건 종류별 발생건수>')

# %% [markdown]
# ### 접수부서완료일시에서 발생일, 발생시간 추출

# %%
tt21
# Out:
#         접수부서코드                       접수완료일시  경찰청구분  사건상태코드  사건종별코드  신고성별  \
# 14         충남청  21/03/07 00:02:48.000000000     19      10     406   1.0
# 44         충남청  21/03/07 00:12:08.000000000     19      10     403   2.0
# 48         충남청  21/03/07 00:13:32.000000000     19      10     406   1.0
# 65         충남청  21/03/07 02:06:29.000000000     19      10     403   1.0
# 70         충남청  21/03/07 02:08:26.000000000     19      10     403   3.0
# ...        ...                          ...    ...     ...     ...   ...
# 2593729    충남청  23/01/18 16:06:19.000000000     19      10     403   3.0
# 2593799    대전청  23/01/14 17:01:35.000000000     13      10     406   2.0
# 2593809    충남청  23/01/14 10:43:37.000000000     31      10     403   3.0
# 2593811    충남청  23/01/18 13:00:37.000000000     19      10     403   1.0
# 2594006    충남청  23/01/14 01:02:48.000000000     19      10     403   2.0
#
#                                      발생지점       발생좌표x      발생좌표y 동일사건여부
# 14             충청남도 천안시 서북구 불당동(불당동) 1625  127.107500  36.811944    NaN
# 44                      충청남도 공주시 우성면 평목리   127.090733  36.453397    NaN
# 48                 충청남도 당진시 송산면 상거리 321-6  126.680044  36.933368    NaN
# 65             충청남도 천안시 서북구 백석동(백석동) 52-6  127.127337  36.833938      N
# 70            충청남도 천안시 서북구 백석동(백석동) 325-5  127.118560  36.822827      Y
# ...                                   ...         ...        ...    ...
# 2593729  충청남도 천안시 동남구 신부동 (행정:신안동 ) 459-8  127.156334  36.817797      Y
# 2593799        대전광역시 유성구 지족동 (노은3동 ) 1041  127.304497  36.381533      Y
# 2593809      세종특별자치시 세종시 나성동 (새롬동 ) 568-3  127.262664  36.478976      Y
# 2593811     충청남도 당진시 합덕읍 성동리(합덕읍 ) 435-21  126.768976  36.793109    NaN
# 2594006     충청남도 천안시 동남구 다가동 (일봉동 ) 61-35  127.147678  36.789125    NaN
#
# [76250 rows x 10 columns]

# %%
# datetime을 사용하면 시간이 이상하게 설정되어 직접 슬라이싱
tt21["접수완료연월일"]=tt21["접수완료일시"].apply(lambda x:x[0:-18])

tt21.head(3)
# Out:
# C:\Users\minir\AppData\Local\Temp\ipykernel_24748\1179802541.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt21["접수완료연월일"]=tt21["접수완료일시"].apply(lambda x:x[0:-18])
#    접수부서코드                       접수완료일시  경찰청구분  사건상태코드  사건종별코드  신고성별  \
# 14    충남청  21/03/07 00:02:48.000000000     19      10     406   1.0
# 44    충남청  21/03/07 00:12:08.000000000     19      10     403   2.0
# 48    충남청  21/03/07 00:13:32.000000000     19      10     406   1.0
#
#                           발생지점       발생좌표x      발생좌표y 동일사건여부    접수완료연월일
# 14  충청남도 천안시 서북구 불당동(불당동) 1625  127.107500  36.811944    NaN  21/03/07
# 44           충청남도 공주시 우성면 평목리   127.090733  36.453397    NaN  21/03/07
# 48      충청남도 당진시 송산면 상거리 321-6  126.680044  36.933368    NaN  21/03/07

# %%
tt21["접수완료시각"]=tt21["접수완료일시"].apply(lambda x:x[8:17])
tt21.head(3)
# Out:
# C:\Users\minir\AppData\Local\Temp\ipykernel_24748\2864951427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt21["접수완료시각"]=tt21["접수완료일시"].apply(lambda x:x[8:17])
#    접수부서코드                       접수완료일시  경찰청구분  사건상태코드  사건종별코드  신고성별  \
# 14    충남청  21/03/07 00:02:48.000000000     19      10     406   1.0
# 44    충남청  21/03/07 00:12:08.000000000     19      10     403   2.0
# 48    충남청  21/03/07 00:13:32.000000000     19      10     406   1.0
#
#                           발생지점       발생좌표x      발생좌표y 동일사건여부    접수완료연월일  \
# 14  충청남도 천안시 서북구 불당동(불당동) 1625  127.107500  36.811944    NaN  21/03/07
# 44           충청남도 공주시 우성면 평목리   127.090733  36.453397    NaN  21/03/07
# 48      충청남도 당진시 송산면 상거리 321-6  126.680044  36.933368    NaN  21/03/07
#
#        접수완료시각
# 14   00:02:48
# 44   00:12:08
# 48   00:13:32

# %% [markdown]
# ### 대전청, 호남청 범주형 데이터 나누기

# %%
tt21.replace({"충남청":1}, inplace=True) # 충남 - 1
tt21.replace({"대전청":2}, inplace=True) # 대전 - 2
# Out:
# C:\Users\minir\AppData\Local\Temp\ipykernel_24748\1997401281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt21.replace({"충남청":1}, inplace=True) # 충남 - 1
# C:\Users\minir\AppData\Local\Temp\ipykernel_24748\1997401281.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t
# 845         충청남도 아산시 염치읍 백암리(염치읍) 266-19  127.025578  36.800691    NaN
# 877          세종특별자치시 세종시 대평동(대평동) 484-50  127.270281  36.466455    NaN
# 916            충청남도 아산시 둔포면 신남리(행정:둔포면)   127.013430  36.913705    NaN
# 923            충청남도 예산군 응봉면 입침리(응봉면) 산14  126.800000  36.660833    NaN
# 964        충청남도 천안시 동남구 동면 화계리(동면) 523-1  127.345027  36.775288    NaN
# 1054                                 NaN  127.404663  36.341685    NaN
# 1233  충청남도 천안시 서북구 입장면 용정리(행정:입장면) 83-27  127.188720  36.914290    NaN
# 1281       충청남도 천안시 서북구 성거읍 요방리(성거읍) 121  127.180833  36.855278    NaN
# 1423          충청남도 서산시 읍내동(행정:부춘동) 21-11  126.452533  36.776954    NaN
# 1622            세종특별자치시 세종시 한솔동(한솔동) 939  127.257425  36.478547    NaN
# 1623         세종특별자치시 세종시 한솔동(행정:한솔동) 943  127.259107  36.480312    NaN
# 1880            대전광역시 동구 삼성동(삼성동) 295-46  127.429539  36.338033      Y
# 1887      충청남도 금산군 금산읍 중도리(행정:금산읍) 229-3  127.493193  36.105251    NaN
# 1912       대전광역시 유성구 봉명동(행정:원신흥동) 1029-2  127.341045  36.348022      Y
#
#         접수완료연월일     접수완료시각
# 14    21/03/07    00:02:48
# 44    21/03/07    00:12:08
# 48    21/03/07    00:13:32
# 65    21/03/07    02:06:29
# 70    21/03/07    02:08:26
# 71    21/03/07    02:08:19
# 72    21/03/07    02:07:53
# 84    21/03/07    02:11:05
# 86    21/03/07    02:10:59
# 94    21/03/07    02:16:39
# 98    21/03/07    02:13:35
# 99    21/03/07    02:15:05
# 102   21/03/07    02:14:58
# 113   21/03/07    02:18:03
# 114   21/03/07    02:17:59
# 116   21/03/07    02:17:57
# 122   21/03/07    02:24:14
# 191   21/01/03    00:22:46
# 232   21/01/01    15:07:00
# 301   21/01/01    15:16:29
# 393   21/01/01    16:13:53
# 441   21/01/01    16:18:56
# 448   21/01/01    16:48:41
# 580   21/01/01    01:52:33
# 607   21/01/01    02:14:35
# 609   21/01/01    01:56:36
# 623   21/01/01    02:00:45
# 638   21/01/01    02:05:10
# 642   21/01/01    01:57:42
# 651   21/01/01    01:49:30
# 654   21/01/01    02:05:26
# 688   21/01/01    02:25:41
# 705   21/01/01    03:01:32
# 707   21/01/01    03:03:31
# 724   21/01/01    02:48:50
# 751   21/01/01    03:18:36
# 845   21/01/01    13:05:00
# 877   21/01/01    12:47:19
# 916   21/01/01    13:32:14
# 923   21/01/01    13:32:32
# 964   21/01/01    13:52:51
# 1054  21/01/01    04:09:04
# 1233  21/01/01    07:38:22
# 1281  21/01/03    00:47:01
# 1423  21/01/03    07:33:07
# 1622  21/01/02    13:12:16
# 1623  21/01/02    13:12:44
# 1880  21/01/01    22:51:02
# 1887  21/01/01    22:36:57
# 1912  21/01/01    23:05:19

# %% [markdown]
# ### 발생지점에서 시와 구 추출

# %%
# 발생지점에서 시 추출
tt21["대분류지역"]=tt21["발생지점"].str.split(" ").str[0]
# Out:
# C:\Users\minir\AppData\Local\Temp\ipykernel_24748\810470993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt21["대분류지역"]=tt21["발생지점"].str.split(" ").str[0]

# %%
# 발생지점에서 구 추출
tt21["발생시구"]=tt21["발생지점"].str.split(" ").str[1]
# Out:
# C:\Users\minir\AppData\Local\Temp\ipykernel_24748\1596707597.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt21["발생시구"]=tt21["발생지점"].str.split(" ").str[1]

# %%
tt21
# Out:
#         접수부서코드                       접수완료일시  경찰청구분  사건상태코드  사건종별코드  신고성별  \
# 14           1  21/03/07 00:02:48.000000000     19      10     406   1.0
# 44           1  21/03/07 00:12:08.000000000     19      10     403   2.0
# 48           1  21/03/07 00:13:32.000000000     19      10     406   1.0
# 65           1  21/03/07 02:06:29.000000000     19      10     403   1.0
# 70           1  21/03/07 02:08:26.000000000     19      10     403   3.0
# ...        ...                          ...    ...     ...     ...   ...
# 2593729      1  23/01/18 16:06:19.000000000     19      10     403   3.0
# 2593799      2  23/01/14 17:01:35.000000000     13      10     406   2.0
# 2593809      1  23/01/14 10:43:37.000000000     31      10     403   3.0
# 2593811      1  23/01/18 13:00:37.000000000     19      10     403   1.0
# 2594006      1  23/01/14 01:02:48.000000000     19      10     403   2.0
#
#                                      발생지점       발생좌표x      발생좌표y 동일사건여부  \
# 14             충청남도 천안시 서북구 불당동(불당동) 1625  127.107500  36.811944    NaN
# 44                      충청남도 공주시 우성면 평목리   127.090733  36.453397    NaN
# 48                 충청남도 당진시 송산면 상거리 321-6  126.680044  36.933368    NaN
# 65             충청남도 천안시 서북구 백석동(백석동) 52-6  127.127337  36.833938      N
# 70            충청남도 천안시 서북구 백석동(백석동) 325-5  127.118560  36.822827      Y
# ...                                   ...         ...        ...    ...
# 2593729  충청남도 천안시 동남구 신부동 (행정:신안동 ) 459-8  127.156334  36.817797      Y
# 2593799        대전광역시 유성구 지족동 (노은3동 ) 1041  127.304497  36.381533      Y
# 2593809      세종특별자치시 세종시 나성동 (새롬동 ) 568-3  127.262664  36.478976      Y
# 2593811     충청남도 당진시 합덕읍 성동리(합덕읍 ) 435-21  126.768976  36.793109    NaN
# 2594006     충청남도 천안시 동남구 다가동 (일봉동 ) 61-35  127.147678  36.789125    NaN
#
#            접수완료연월일     접수완료시각    대분류지역 발생시구
# 14       21/03/07    00:02:48     충청남도  천안시
# 44       21/03/07    00:12:08     충청남도  공주시
# 48       21/03/07    00:13:32     충청남도  당진시
# 65       21/03/07    02:06:29     충청남도  천안시
# 70       21/03/07    02:08:26     충청남도  천안시
# ...            ...        ...      ...  ...
# 2593729  23/01/18    16:06:19     충청남도  천안시
# 2593799  23/01/14    17:01:35    대전광역시  유성구
# 2593809  23/01/14    10:43:37  세종특별자치시  세종시
# 2593811  23/01/18    13:00:37     충청남도  당진시
# 2594006  23/01/14    01:02:48     충청남도  천안시
#
# [76250 rows x 14 columns]

# %% [markdown]
# ### 지역분류별 발생건수 그래프

# %%
len(tt21[tt21["대분류지역"]=="충청남도"])
# Out:
# 47896

# %%
len(tt21[tt21["대분류지역"]=="대전광역시"])
# Out:
# 20263

# %%
len(tt21[tt21["대분류지역"]=="세종특별자치시"])
# Out:
# 5123

# %%
tt21_cn=len(tt21[tt21["대분류지역"]=="충청남도"])
tt21_dj=len(tt21[tt21["대분류지역"]=="대전광역시"])
tt21_sj=len(tt21[tt21["대분류지역"]=="세종특별자치시"])

tt21_si_list=[["충청남도",tt21_cn],["대전광역시",tt21_dj],["세종시",tt21_sj]]
tt21si=pd.DataFrame(tt21_si_list, columns=["지역 분류","발생건수"])

# %%
tt21si=tt21si.set_index("지역 분류")
tt21si.sort_values("발생건수", ascending=False)
# Out:
#         발생건수
# 지역 분류
# 충청남도   47896
# 대전광역시  20263
# 세종시     5123

# %%
tt21si.plot(kind="bar", figsize=(10,10), color="Skyblue")
plt.xlabel("지역 분류", fontsize=12)
plt.ylabel("발생건수", fontsize=15)
plt.title("21년도 사건 발생건수", fontsize=15)
plt.xticks(rotation = 60, fontsize=12)
plt.yticks(fontsize=12)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
tt21
# Out:
#         접수부서코드                       접수완료일시  경찰청구분  사건상태코드  사건종별코드  신고성별  \
# 14           1  21/03/07 00:02:48.000000000     19      10     406   1.0
# 44           1  21/03/07 00:12:08.000000000     19      10     403   2.0
# 48           1  21/03/07 00:13:32.000000000     19      10     406   1.0
# 65           1  21/03/07 02:06:29.000000000     19      10     403   1.0
# 70           1  21/03/07 02:08:26.000000000     19      10     403   3.0
# ...        ...                          ...    ...     ...     ...   ...
# 2593729      1  23/01/18 16:06:19.000000000     19      10     403   3.0
# 2593799      2  23/01/14 17:01:35.000000000     13      10     406   2.0
# 2593809      1  23/01/14 10:43:37.000000000     31      10     403   3.0
# 2593811      1  23/01/18 13:00:37.000000000     19      10     403   1.0
# 2594006      1  23/01/14 01:02:48.000000000     19      10     403   2.0
#
#                                      발생지점       발생좌표x      발생좌표y 동일사건여부  \
# 14             충청남도 천안시 서북구 불당동(불당동) 1625  127.107500  36.811944    NaN
# 44                      충청남도 공주시 우성면 평목리   127.090733  36.453397    NaN
# 48                 충청남도 당진시 송산면 상거리 321-6  126.680044  36.933368    NaN
# 65             충청남도 천안시 서북구 백석동(백석동) 52-6  127.127337  36.833938      N
# 70            충청남도 천안시 서북구 백석동(백석동) 325-5  127.118560  36.822827      Y
# ...                                   ...         ...        ...    ...
# 2593729  충청남도 천안시 동남구 신부동 (행정:신안동 ) 459-8  127.156334  36.817797      Y
# 2593799        대전광역시 유성구 지족동 (노은3동 ) 1041  127.304497  36.381533      Y
# 2593809      세종특별자치시 세종시 나성동 (새롬동 ) 568-3  127.262664  36.478976      Y
# 2593811     충청남도 당진시 합덕읍 성동리(합덕읍 ) 435-21  126.768976  36.793109    NaN
# 2594006     충청남도 천안시 동남구 다가동 (일봉동 ) 61-35  127.147678  36.789125    NaN
#
#            접수완료연월일     접수완료시각    대분류지역 발생시구
# 14       21/03/07    00:02:48     충청남도  천안시
# 44       21/03/07    00:12:08     충청남도  공주시
# 48       21/03/07    00:13:32     충청남도  당진시
# 65       21/03/07    02:06:29     충청남도  천안시
# 70       21/03/07    02:08:26     충청남도  천안시
# ...            ...        ...      ...  ...
# 2593729  23/01/18    16:06:19     충청남도  천안시
# 2593799  23/01/14    17:01:35    대전광역시  유성구
# 2593809  23/01/14    10:43:37  세종특별자치시  세종시
# 2593811  23/01/18    13:00:37     충청남도  당진시
# 2594006  23/01/14    01:02:48     충청남도  천안시
#
# [76250 rows x 14 columns]
